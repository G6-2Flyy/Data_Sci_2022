# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import pymongo

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Downloading: 100%|█████████████████| 8.61M/8.61M [00:00<00:00, 15.0MB/s]

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com'
browser.visit(url)

# %%
html = browser.html
html[0:500]
# Out:
# '<html><head>\n      <meta charset="utf-8">\n      <meta name="viewport" content="width=device-width, initial-scale=1">\n      <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" crossorigin="anonymous">\n      <link rel="stylesheet" type="text/css" href="css/font.css">\n      <link rel="stylesheet" type="text/css" href="css/app.css">\n      <link rel="stylesheet" '

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
soup = soup(html) 
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Extract all the text elements
news_articles = soup.find_all
news_articles
# Out:
# <bound method Tag.find_all of <html><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet" type="text/css"/>
# <link href="css/app.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
# <title>News - Mars Exploration Program</title>
# </head>
# <body>
# <div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# ...

# %%
news_articles = soup.find_all("div", {"class": "list_text"})
len(news_articles)
# Out:
# 15

# %%
news_article = news_articles[2]
news_article
# Out:
# <div class="list_text">
# <div class="list_date">December 31, 2022</div>
# <div class="content_title">Mars Scientists Investigate Ancient Life in Australia</div>
# <div class="article_teaser_body">Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. </div>
# </div>

# %%
news_article.find("div", {"class": "content_title"}).text
# Out:
# 'Mars Scientists Investigate Ancient Life in Australia'

# %%
news_article.find("div", {"class": "article_teaser_body"}).text
# Out:
# "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "

# %%
news_article.find("div", {"class": "list_date"}).text
# Out:
# 'December 31, 2022'

# %%
for news_article in soup.find_all('img'):
    print(news_article['src'])
# Out:
# image/nasa.png
# https://mars.nasa.gov/system/news_items/list_view_images/8731_MAVEN_nightglow_pulsating_spot-320x240.jpg
# https://mars.nasa.gov/system/news_items/list_view_images/8595_mars_winds_preview_4-320x240.jpg
# https://mars.nasa.gov/system/news_items/list_view_images/8551_PIA23551-320x240.jpg
# https://mars.nasa.gov/system/news_items/list_view_images/8704_PIA23973-320x240.jpg
# https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg
# https://mars.nasa.gov/system/news_items/list_view_images/8503_PIA23319-MAIN-226.jpg
# https://mars.nasa.gov/system/news_items/list_view_images/8649_PIA23828-MAINimage-RoverNamePlate-320x240.jpg
# https://mars.nasa.gov/system/news_items/list_view_images/8756_25254_Christina_hernandez_mainmax-320x240.png
# https://mars.nasa.gov/system/news_items/list_view_images/8531_PIA23467-320x240.gif
# https://mars.nasa.gov/system/news_items/list_view_images/8691_rover-overlay-226.jpg
# ...

# %%
news_article.find("img", {"src": "list_image"})
print(news_article['src'])
# Out:
# https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&q=80&fm=jpg&crop=entropy&cs=tinysrgb&w=1080&fit=max&ixid=eyJhcHBfaWQiOjMyMDc0fQ&s=5ee4fd5d19b40f93eadb21871757eda6

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Create an empty list to store the dictionaries
data = []

# %%
# Loop through the text elements
# Extract the title and preview text from the elements
# Store each title and preview pair in a dictionary
# Add the dictionary to the list

for news_article in news_articles:
    title = news_article.find("div", {"class": "content_title"}).text
    preview = news_article.find("div", {"class": "article_teaser_body"}).text
    date = news_article.find("div", {"class": "list_date"}).text
    
    row = {}
    row["title"] = title
    row["preview"] = preview
    row["date"] = date
    
    data.append(row)
    
df = pd.DataFrame(data)
df
# Out:
#                                                 title  \
# 0   NASA's MAVEN Observes Martian Night Sky Pulsin...
# 1   NASA's MAVEN Maps Winds in the Martian Upper A...
# 2   Mars Scientists Investigate Ancient Life in Au...
# 3   Curiosity Mars Rover's Summer Road Trip Has Begun
# 4   Alabama High School Student Names NASA's Mars ...
# 5     Robotic Toolkit Added to NASA's Mars 2020 Rover
# 6        NASA's Perseverance Mars Rover Gets Balanced
# 7                                My Culture, My Voice
# 8      Mars 2020 Unwrapped and Ready for More Testing
# 9   While Stargazing on Mars, NASA's Curiosity Rov...
# 10  NASA Perseverance Mars Rover Scientists Train ...
# 11  Heat and Dust Help Launch Martian Water Into S...
# 12        NASA Wins 4 Webbys, 4 People's Voice Awards
# 13  NASA's Perseverance Rover Bringing 3D-Printed ...
# 14  NASA Moves Forward With Campaign to Return Mar...
#
#                                               preview               date
# ...

# %%
# Print the list to confirm success

# %%
browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON
df.to_json("mars_news.json", orient="records")
